# %%
import numpy as np
import pandas as pd

df = pd.read_excel('Dataset.xlsx')
len(df)
df['GB_flag'].value_counts()
# Out:
# GB_flag
# 0    71936
# 1      570
# Name: count, dtype: int64

# %%
desc = pd.read_excel('Variables_description.xlsx')

# %%
df.head(-5)
df[df['GB_flag'] == 1]
# Out:
#        total_amount_kzt  overdueinstalmentcount_po_subektu  term  GB_flag  \
# 607              911321                                NaN  1827        1
# 766             1727428                                NaN  1339        1
# 783             1899853                                0.0  1827        1
# 1019            1080000                                0.0  1096        1
# 1135             107527                                0.0   182        1
# ...                 ...                                ...   ...      ...
# 63947           1300000                                0.0  1095        1
# 64123            164000                                0.0   546        1
# 65457           1737900                                0.0  1826        1
# 65592           4409803                               95.0  2434        1
# 65842           2278400                                NaN  1826        1
#
#        was_canceled  GENDER  CLASSIFICATION  RESIDENCY  EDUCATION  \
# 607               0   515.0            24.0       30.0        NaN
# 766               1   515.0            24.0       30.0       53.0
# 783               0   515.0            24.0       30.0        NaN
# 1019              0   516.0            24.0       30.0        NaN
# 1135              0   515.0            24.0       30.0        NaN
# ...             ...     ...             ...        ...        ...
# 63947             0   515.0            24.0       30.0       53.0
# 64123             0   515.0            24.0       30.0        NaN
# 65457             0   515.0            24.0       30.0        NaN
# 65592             0   515.0            24.0       30.0        NaN
# 65842             0   515.0            24.0       30.0       53.0
#
#        MARITALSTATUS  ...          AS3M  outstandingamount  overdueamount  \
# 607             33.0  ...   38774.04000       9.116555e+05       0.000000
# 766             34.0  ...  157587.00000       1.613281e+06       0.000000
# 783             34.0  ...  714121.80000       3.011494e+06       0.000000
# 1019             NaN  ...   98578.50000       0.000000e+00       0.000000
# 1135             NaN  ...   79210.22685       1.500553e+05       0.000000
# ...              ...  ...           ...                ...            ...
# 63947           34.0  ...           NaN       3.760046e+04       0.000000
# 64123            NaN  ...  113111.72000       0.000000e+00       0.000000
# 65457           33.0  ...           NaN       3.861424e+06       0.000000
# 65592           34.0  ...           NaN       1.802358e+07  720351.577064
# 65842           33.0  ...  400141.82000       1.959198e+06       0.000000
#
#        instalmentamount  loans  frequency      monetary    recency  rfm_score  \
# 607        58373.667380    2.0        5.0  1.606141e+06    34.0816      433.0
# 766        49425.844574    1.0        3.0  5.687627e+06    55.3826      425.0
# 783       103524.965264    1.0        4.0  5.505739e+06    19.1709      535.0
# 1019           0.000000    1.0        2.0  2.719489e+05   476.8381      311.0
# 1135          50.000606    2.0        3.0  1.860341e+06     7.9118      524.0
# ...                 ...    ...        ...           ...        ...        ...
# 63947       9400.286736    1.0        6.0  5.729631e+06   551.3916      345.0
# 64123       2838.161757    1.0        1.0  1.445302e+05  3014.7001      111.0
# 65457     188285.985454    4.0       10.0  6.799358e+06    35.2988      445.0
# 65592     477080.537803    5.0        8.0  2.325319e+07   528.2648      345.0
# 65842     102630.235927    3.0        4.0  3.652086e+06   602.8183      334.0
#
#           DTI3M
# 607    1.505483
# 766    0.313642
# 783    0.144968
# 1019   0.000000
# 1135   0.000631
# ...         ...
# 63947       NaN
# 64123  0.025092
# 65457       NaN
# 65592       NaN
# 65842  0.256485
#
# [570 rows x 177 columns]

# %%
df.isnull().sum(axis = 0).sort_values()
# Out:
# total_amount_kzt         0
# MONTH_OVERDUE_A15        0
# MONTH_OVERDUE_A16        0
# MONTH_OVERDUE_A17        0
# MONTH_OVERDUE_A18        0
#                      ...
# outstandingamount    49784
# overdueamount        49784
# instalmentamount     49784
# DTI3M                57662
# NEGATIVESTATUS       60267
# Length: 177, dtype: int64

# %%
desc.head()
for i in range(len(desc)):
    print(desc.iloc[i])
# Out:
# GB_flag                                    total_amount_kzt
# Флаг хороший/ плохой (таргет)    Сумма выдачи займа в тенге
# Name: 0, dtype: object
# GB_flag                                          overdueinstalmentcount_po_subektu
# Флаг хороший/ плохой (таргет)    Макс. кол-во дней просрочки за все время по вс...
# Name: 1, dtype: object
# GB_flag                                                                 term
# Флаг хороший/ плохой (таргет)    Продолжительность контракта при выдаче, дни
# Name: 2, dtype: object
# GB_flag                                                               was_canceled
# Флаг хороший/ плохой (таргет)    Списывался у Физ.лица ли какой-либо займ до мо...
# Name: 3, dtype: object
# GB_flag                                GENDER
# Флаг хороший/ плохой (таргет)    Пол заёмщика
# Name: 4, dtype: object
# GB_flag                                  CLASSIFICATION
# Флаг хороший/ плохой (таргет)    Классификация Физ лица
# Name: 5, dtype: object
# GB_flag                            RESIDENCY
# Флаг хороший/ плохой (таргет)    Гражданство
# Name: 6, dtype: object
# GB_flag                            EDUCATION
# Флаг хороший/ плохой (таргет)    Образование
# Name: 7, dtype: object
# GB_flag                               MARITALSTATUS
# Флаг хороший/ плохой (таргет)    Семейное положение
# Name: 8, dtype: object
# GB_flag                             NEGATIVESTATUS
# Флаг хороший/ плохой (таргет)    Негативный статус
# Name: 9, dtype: object
# GB_flag                                    PROFESSION
# Флаг хороший/ плохой (таргет)    Название профессии\t
# Name: 10, dtype: object
# GB_flag                          ECONOMYACTIVITYGROUP
# Флаг хороший/ плохой (таргет)       Отрасль экономики
# Name: 11, dtype: object
# GB_flag                          EMPLOYMENTNATURE
# Флаг хороший/ плохой (таргет)    Вид деятельности
# Name: 12, dtype: object
# GB_flag                                                     SALARY
# Флаг хороший/ плохой (таргет)    Заработная плата по данным БДКИ\t
# Name: 13, dtype: object
# GB_flag                                          DEPENDANTS_LT18
# Флаг хороший/ плохой (таргет)    Количество иждивенцев до 18 лет
# Name: 14, dtype: object
# GB_flag                                              DEPENDANTS_GT18
# Флаг хороший/ плохой (таргет)    Количество иждивенцев старше 18 лет
# Name: 15, dtype: object
# GB_flag                                       AGE
# Флаг хороший/ плохой (таргет)    Число полных лет
# Name: 16, dtype: object
# GB_flag                                                           NUM_CONTRACT_BVU
# Флаг хороший/ плохой (таргет)    Кол-во контрактов заёмщика в БВУ до расчетной ...
# Name: 17, dtype: object
# GB_flag                                                           NUM_CONTRACT_MFO
# Флаг хороший/ плохой (таргет)    Кол-во контрактов заёмщика в МФО до расчетной ...
# Name: 18, dtype: object
# GB_flag                                                           NUM_CONTRACT_PDL
# Флаг хороший/ плохой (таргет)    Кол-во контрактов заёмщика в PDL до расчетной ...
# Name: 19, dtype: object
# GB_flag                                                        NUM_CONTRACT_OTHERS
# Флаг хороший/ плохой (таргет)    Кол-во контрактов заёмщика в иных до расчетной...
# Name: 20, dtype: object
# GB_flag                                                             NUM_COLLATERAL
# Флаг хороший/ плохой (таргет)    Количество залогового имущество за все время с...
# Name: 21, dtype: object
# GB_flag                                                                 NUM_USAGES
# Флаг хороший/ плохой (таргет)    Количество запросов за все время существования...
# Name: 22, dtype: object
# GB_flag                                                                     CNT_3D
# Флаг хороший/ плохой (таргет)    Количество запросов за последние 3 дня до расч...
# Name: 23, dtype: object
# GB_flag                                                                     CNT_1M
# Флаг хороший/ плохой (таргет)    Количество запросов за последние 1 месяцов до ...
# Name: 24, dtype: object
# GB_flag                                                                     CNT_3M
# Флаг хороший/ плохой (таргет)    Количество запросов за последние 3 месяцов до ...
# Name: 25, dtype: object
# GB_flag                                                                     CNT_6M
# Флаг хороший/ плохой (таргет)    Количество запросов за последние 6 месяцов до ...
# Name: 26, dtype: object
# GB_flag                                             MAX_PEAKS_OVERDUECOUNT_LAST_2Y
# Флаг хороший/ плохой (таргет)    Максимальное количество пиков (т. е. начало и ...
# Name: 27, dtype: object
# GB_flag                                            MEAN_PEAKS_OVERDUECOUNT_LAST_2Y
# Флаг хороший/ плохой (таргет)    Среднее количество пиков по всем контрактам су...
# Name: 28, dtype: object
# GB_flag                                        MEAN_SIG_PEAKS_OVERDUECOUNT_LAST_2Y
# Флаг хороший/ плохой (таргет)    Среднее количество взвешенных пиков по всем ко...
# Name: 29, dtype: object
# GB_flag                                         SUM_SIG_PEAKS_OVERDUECOUNT_LAST_2Y
# Флаг хороший/ плохой (таргет)    Сумма всех взвешенных пиков субъекта по каждым...
# Name: 30, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C0
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 31, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C1
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 32, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C2
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 33, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C3
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 34, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C4
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 35, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C5
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 36, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C6
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 37, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C7
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 38, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C8
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 39, dtype: object
# GB_flag                                                           MONTH_OVERDUE_C9
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 40, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C10
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 41, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C11
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 42, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C12
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 43, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C13
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 44, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C14
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 45, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C15
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 46, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C16
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 47, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C17
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 48, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C18
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 49, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C19
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 50, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C20
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 51, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C21
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 52, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C22
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 53, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C23
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 54, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C24
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 55, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C25
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 56, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C26
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 57, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C27
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 58, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C28
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 59, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C29
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 60, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C30
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 61, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C31
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 62, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C32
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 63, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C33
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 64, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C34
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 65, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C35
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 66, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C36
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 67, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C37
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 68, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C38
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 69, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C39
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 70, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C40
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 71, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C41
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 72, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C42
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 73, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C43
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 74, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C44
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 75, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C45
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 76, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C46
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 77, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C47
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 78, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C48
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 79, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C49
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 80, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C50
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 81, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C51
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 82, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C52
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 83, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C53
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 84, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C54
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 85, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C55
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 86, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C56
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 87, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C57
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 88, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C58
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 89, dtype: object
# GB_flag                                                          MONTH_OVERDUE_C59
# Флаг хороший/ плохой (таргет)    Максимальное количество просрочек по всем его ...
# Name: 90, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A0
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 91, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A1
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 92, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A2
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 93, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A3
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 94, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A4
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 95, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A5
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 96, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A6
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 97, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A7
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 98, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A8
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 99, dtype: object
# GB_flag                                                           MONTH_OVERDUE_A9
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 100, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A10
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 101, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A11
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 102, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A12
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 103, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A13
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 104, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A14
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 105, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A15
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 106, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A16
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 107, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A17
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 108, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A18
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 109, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A19
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 110, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A20
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 111, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A21
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 112, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A22
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 113, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A23
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 114, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A24
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 115, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A25
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 116, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A26
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 117, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A27
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 118, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A28
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 119, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A29
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 120, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A30
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 121, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A31
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 122, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A32
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 123, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A33
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 124, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A34
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 125, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A35
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 126, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A36
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 127, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A37
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 128, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A38
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 129, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A39
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 130, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A40
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 131, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A41
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 132, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A42
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 133, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A43
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 134, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A44
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 135, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A45
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 136, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A46
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 137, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A47
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 138, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A48
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 139, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A49
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 140, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A50
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 141, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A51
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 142, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A52
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 143, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A53
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 144, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A54
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 145, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A55
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 146, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A56
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 147, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A57
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 148, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A58
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 149, dtype: object
# GB_flag                                                          MONTH_OVERDUE_A59
# Флаг хороший/ плохой (таргет)    Максимальная сумма просрочек по всем его креди...
# Name: 150, dtype: object
# GB_flag                                        NUM_ADDRESSES
# Флаг хороший/ плохой (таргет)    Количество адресов субъекта
# Name: 151, dtype: object
# GB_flag                                                NUM_PHONENUMBERS
# Флаг хороший/ плохой (таргет)    Количество телефонных номеров субъекта
# Name: 152, dtype: object
# GB_flag                                                              NUM_CONTRACTS
# Флаг хороший/ плохой (таргет)    Общие количество контрактов заёмщика до расчет...
# Name: 153, dtype: object
# GB_flag                                                            TOTALAMOUNT_MIN
# Флаг хороший/ плохой (таргет)    Минимальная величина активного займа в тенге д...
# Name: 154, dtype: object
# GB_flag                                                            TOTALAMOUNT_MAX
# Флаг хороший/ плохой (таргет)    Максимальная величина активного займа в тенге ...
# Name: 155, dtype: object
# GB_flag                                                          NUM_CONTRACTS_INS
# Флаг хороший/ плохой (таргет)    Количество контрактов виде рассрочки до расчет...
# Name: 156, dtype: object
# GB_flag                                                          NUM_CONTRACTS_NIN
# Флаг хороший/ плохой (таргет)    Количество контрактов виде нон-рассрочки, кред...
# Name: 157, dtype: object
# GB_flag                                                        NUM_CONTRACTS_OTHER
# Флаг хороший/ плохой (таргет)    Количество контрактов виде страховки до расчет...
# Name: 158, dtype: object
# GB_flag                                                          NUM_CONTRACTS_FOR
# Флаг хороший/ плохой (таргет)    Количество контрактов в иностранной валюте до ...
# Name: 159, dtype: object
# GB_flag                                               NUM_MONTH_BTW_LAST_CONTRACTS
# Флаг хороший/ плохой (таргет)    Количество месяцев между последним и пред-посл...
# Name: 160, dtype: object
# GB_flag                                                   NUM_MONTH_FROM_START_MAX
# Флаг хороший/ плохой (таргет)    Количество месяцев от первого контракта заёмщи...
# Name: 161, dtype: object
# GB_flag                                                   NUM_MONTH_FROM_START_MIN
# Флаг хороший/ плохой (таргет)    Количество месяцев от последнего контракта заё...
# Name: 162, dtype: object
# GB_flag                                                  NUM_CONTRACTS_STARTED_L3M
# Флаг хороший/ плохой (таргет)    Количество контрактов заёмщика за 3 мес. до ра...
# Name: 163, dtype: object
# GB_flag                                                  NUM_CONTRACTS_STARTED_L6M
# Флаг хороший/ плохой (таргет)    Количество контрактов заёмщика за 6 мес. до ра...
# Name: 164, dtype: object
# GB_flag                                                 NUM_CONTRACTS_STARTED_L12M
# Флаг хороший/ плохой (таргет)    Количество контрактов заёмщика за 12 мес. до р...
# Name: 165, dtype: object
# GB_flag                                               NUM_CONTRACTS_STARTED_L7_12M
# Флаг хороший/ плохой (таргет)    Количество контрактов заёмщика за от 6 до 12 м...
# Name: 166, dtype: object
# GB_flag                                                                       AS3M
# Флаг хороший/ плохой (таргет)    Среднемесячная чистая ЗП за 3 мес. предшедству...
# Name: 167, dtype: object
# GB_flag                          outstandingamount
# Флаг хороший/ плохой (таргет)        Задолженность
# Name: 168, dtype: object
# GB_flag                                       overdueamount
# Флаг хороший/ плохой (таргет)    Просроченная задолженность
# Name: 169, dtype: object
# GB_flag                                                           instalmentamount
# Флаг хороший/ плохой (таргет)    Сумма платежей в  предыд. месяце  к расчетной ...
# Name: 170, dtype: object
# GB_flag                                      loans
# Флаг хороший/ плохой (таргет)    количество займов
# Name: 171, dtype: object
# GB_flag                                                                  frequency
# Флаг хороший/ плохой (таргет)    Frequency (от англ. частота) — с какой периоди...
# Name: 172, dtype: object
# GB_flag                                                                   monetary
# Флаг хороший/ плохой (таргет)    Monetary (от англ. деньги) — сколько всего у в...
# Name: 173, dtype: object
# GB_flag                                                                    recency
# Флаг хороший/ плохой (таргет)    Recency (от англ. давность) — этот показатель ...
# Name: 174, dtype: object
# GB_flag                                                 rfm_score
# Флаг хороший/ плохой (таргет)    балл по маркетинговой модели RFM
# Name: 175, dtype: object
# GB_flag                                                           DTI3M
# Флаг хороший/ плохой (таргет)    Коэффициент долговой нагрузки заёмщика
# Name: 176, dtype: object

# %%
df['NEGATIVESTATUS'].value_counts().sum()
# Out:
# 12239

# %%
df['NEGATIVESTATUS'].isnull().sum()
# Out:
# 60267

# %%
df.isnull().sum(axis = 0).sort_values() > len(df) * 0.2
# Out:
# total_amount_kzt     False
# MONTH_OVERDUE_A15    False
# MONTH_OVERDUE_A16    False
# MONTH_OVERDUE_A17    False
# MONTH_OVERDUE_A18    False
#                      ...
# outstandingamount     True
# overdueamount         True
# instalmentamount      True
# DTI3M                 True
# NEGATIVESTATUS        True
# Length: 177, dtype: bool

# %%
s = df.isnull().sum(axis = 0).sort_values() > len(df) * 0.2
s = s[s].index
s
data = df.drop(s, axis = 1)

# %%
s = (data.isnull().sum(axis = 0) > 0)
s = s[s]
data = data.drop(s.index, axis = 1)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.drop(['GB_flag'], axis = 1), data['GB_flag'], test_size=0.2, random_state=42, stratify = data['GB_flag'])

# %%
Train = pd.concat([X_train, y_train], axis = 1)

# %%
Train.isnull().sum().sum()
# Out:
# 0

# %%
correlations = Train.corr()['GB_flag'].drop('GB_flag')

# %%
#################################################################
#        CORRELATION_THREASHOLD pretty arbitrary here
#################################################################
CORRELATION_THREASHOLD = 0.2
features = correlations[abs(correlations) > CORRELATION_THREASHOLD].index

# %%
features
# Out:
# Index(['MONTH_OVERDUE_C0', 'MONTH_OVERDUE_C1', 'MONTH_OVERDUE_C2',
#        'MONTH_OVERDUE_C3', 'MONTH_OVERDUE_C4', 'MONTH_OVERDUE_C5',
#        'MONTH_OVERDUE_C6', 'MONTH_OVERDUE_C7', 'MONTH_OVERDUE_C8',
#        'MONTH_OVERDUE_C9', 'MONTH_OVERDUE_C10', 'MONTH_OVERDUE_C11',
#        'MONTH_OVERDUE_C12', 'MONTH_OVERDUE_C13', 'MONTH_OVERDUE_C14',
#        'MONTH_OVERDUE_C15', 'MONTH_OVERDUE_C16', 'MONTH_OVERDUE_C17',
#        'MONTH_OVERDUE_C18', 'MONTH_OVERDUE_C19', 'MONTH_OVERDUE_C20',
#        'MONTH_OVERDUE_C21', 'MONTH_OVERDUE_C22', 'MONTH_OVERDUE_C23',
#        'MONTH_OVERDUE_A0', 'MONTH_OVERDUE_A1', 'MONTH_OVERDUE_A2',
#        'MONTH_OVERDUE_A3', 'MONTH_OVERDUE_A4', 'MONTH_OVERDUE_A5',
#        'MONTH_OVERDUE_A6', 'MONTH_OVERDUE_A7', 'MONTH_OVERDUE_A8',
#        'MONTH_OVERDUE_A9', 'MONTH_OVERDUE_A10', 'MONTH_OVERDUE_A11',
#        'MONTH_OVERDUE_A12', 'MONTH_OVERDUE_A13', 'MONTH_OVERDUE_A14',
#        'MONTH_OVERDUE_A17', 'MONTH_OVERDUE_A18', 'MONTH_OVERDUE_A19',
#        'MONTH_OVERDUE_A20', 'MONTH_OVERDUE_A21', 'MONTH_OVERDUE_A22',
#        'MONTH_OVERDUE_A23', 'MONTH_OVERDUE_A24', 'MONTH_OVERDUE_A25',
#        'MONTH_OVERDUE_A26', 'MONTH_OVERDUE_A27', 'MONTH_OVERDUE_A28',
#        'MONTH_OVERDUE_A29', 'MONTH_OVERDUE_A30', 'MONTH_OVERDUE_A31',
#        'MONTH_OVERDUE_A32', 'MONTH_OVERDUE_A33', 'MONTH_OVERDUE_A34',
#        'MONTH_OVERDUE_A35', 'MONTH_OVERDUE_A36', 'MONTH_OVERDUE_A37',
#        'MONTH_OVERDUE_A38', 'MONTH_OVERDUE_A39', 'MONTH_OVERDUE_A40',
#        'MONTH_OVERDUE_A41', 'MONTH_OVERDUE_A56', 'MONTH_OVERDUE_A58'],
#       dtype='object')

# %%
X = data[features]
y = data['GB_flag']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1488, stratify = y)

# %%
pd.DataFrame(y_test).value_counts().sum()
# Out:
# 14502

# %%
pd.DataFrame(y_train).value_counts().sum()
# Out:
# 58004

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()
model.fit(X_train_sc, y_train)

# Make predictions
y_pred = model.predict(X_test_sc)

# Evaluate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.99

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming y_test and y_pred are already defined
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(5, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# donnow if it is any good, apparently data itself is insanely skewed

# %%
X_test.to_csv('X_test_funky', index = False)
X_train.to_csv('X_train_funky', index = False)
y_test.to_csv('y_test_funky', index = False)
y_train.to_csv('y_train_funky', index = False)

# %%
import numpy as np
import pandas as pd


X_test = pd.read_csv('X_test_funky')
X_train = pd.read_csv('X_train_funky')
y_test = pd.read_csv('y_test_funky')
y_train = pd.read_csv('y_train_funky')

# %%
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import precision_recall_curve, auc, average_precision_score

# Define the model
model = CatBoostClassifier(
    iterations=5000,
    learning_rate=0.01,
    depth=6,
    loss_function="Logloss",
    eval_metric="AUC",
    auto_class_weights="Balanced",
    early_stopping_rounds=20,
    verbose=2
)

# Train the model
model.fit(X_train, y_train, eval_set=(X_test, y_test), use_best_model=True)

# Predict probabilities
y_pred_prob = model.predict_proba(X_test)[:, 1]  # Get probability for class 1

# Compute AUC-PR
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
auc_pr = auc(recall, precision)

print(f"AUC-PR: {auc_pr:.4f}")
# Out:
# 0:	test: 0.6488908	best: 0.6488908 (0)	total: 22.8ms	remaining: 1m 53s
# 2:	test: 0.6434578	best: 0.6488908 (0)	total: 55.7ms	remaining: 1m 32s
# 4:	test: 0.6596762	best: 0.6596762 (4)	total: 88.5ms	remaining: 1m 28s
# 6:	test: 0.6745988	best: 0.6745988 (6)	total: 121ms	remaining: 1m 26s
# 8:	test: 0.6559959	best: 0.6745988 (6)	total: 154ms	remaining: 1m 25s
# 10:	test: 0.6671910	best: 0.6745988 (6)	total: 187ms	remaining: 1m 24s
# 12:	test: 0.6703567	best: 0.6745988 (6)	total: 219ms	remaining: 1m 24s
# 14:	test: 0.6729603	best: 0.6745988 (6)	total: 252ms	remaining: 1m 23s
# 16:	test: 0.6743580	best: 0.6745988 (6)	total: 284ms	remaining: 1m 23s
# 18:	test: 0.6738416	best: 0.6745988 (6)	total: 317ms	remaining: 1m 22s
# 20:	test: 0.6750301	best: 0.6750301 (20)	total: 349ms	remaining: 1m 22s
# 22:	test: 0.6714507	best: 0.6750301 (20)	total: 381ms	remaining: 1m 22s
# 24:	test: 0.6663024	best: 0.6750301 (20)	total: 413ms	remaining: 1m 22s
# 26:	test: 0.6681829	best: 0.6750301 (20)	total: 445ms	remaining: 1m 22s
# 28:	test: 0.6775292	best: 0.6775292 (28)	total: 479ms	remaining: 1m 22s
# 30:	test: 0.6816255	best: 0.6816255 (30)	total: 511ms	remaining: 1m 21s
# 32:	test: 0.6836542	best: 0.6836542 (32)	total: 544ms	remaining: 1m 21s
# 34:	test: 0.6834865	best: 0.6836542 (32)	total: 576ms	remaining: 1m 21s
# 36:	test: 0.6757983	best: 0.6836542 (32)	total: 608ms	remaining: 1m 21s
# 38:	test: 0.6736132	best: 0.6836542 (32)	total: 641ms	remaining: 1m 21s
# 40:	test: 0.6736331	best: 0.6836542 (32)	total: 674ms	remaining: 1m 21s
# 42:	test: 0.6779422	best: 0.6836542 (32)	total: 708ms	remaining: 1m 21s
# 44:	test: 0.6766271	best: 0.6836542 (32)	total: 741ms	remaining: 1m 21s
# 46:	test: 0.6773222	best: 0.6836542 (32)	total: 773ms	remaining: 1m 21s
# 48:	test: 0.6792414	best: 0.6836542 (32)	total: 807ms	remaining: 1m 21s
# 50:	test: 0.6852991	best: 0.6852991 (50)	total: 839ms	remaining: 1m 21s
# 52:	test: 0.6829482	best: 0.6852991 (50)	total: 871ms	remaining: 1m 21s
# 54:	test: 0.6779349	best: 0.6852991 (50)	total: 903ms	remaining: 1m 21s
# 56:	test: 0.6771155	best: 0.6852991 (50)	total: 934ms	remaining: 1m 21s
# 58:	test: 0.6784940	best: 0.6852991 (50)	total: 967ms	remaining: 1m 20s
# 60:	test: 0.6722326	best: 0.6852991 (50)	total: 1000ms	remaining: 1m 20s
# 62:	test: 0.6724677	best: 0.6852991 (50)	total: 1.03s	remaining: 1m 20s
# 64:	test: 0.6712047	best: 0.6852991 (50)	total: 1.06s	remaining: 1m 20s
# 66:	test: 0.6717684	best: 0.6852991 (50)	total: 1.1s	remaining: 1m 20s
# 68:	test: 0.6827059	best: 0.6852991 (50)	total: 1.13s	remaining: 1m 20s
# 70:	test: 0.6834679	best: 0.6852991 (50)	total: 1.16s	remaining: 1m 20s
# Stopped by overfitting detector  (20 iterations wait)
#
# bestTest = 0.6852990918
# bestIteration = 50
#
# Shrink model to first 51 iterations.
# AUC-PR: 0.1484

# %%
t = y_train == 0
t[t]
# Out:
#       GB_flag
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 57999    True
# 58000    True
# 58001    True
# 58002    True
# 58003    True
#
# [58004 rows x 1 columns]

# %%
y_train.value_counts()[0]
baseline_auc = y_train.value_counts()[1] / y_train.value_counts()[0]
baseline_auc
# Out:
# 0.007923820115381942

# %%
import xgboost as xgb
from sklearn.metrics import precision_recall_curve, auc

# Define XGBoost parameters
params = {
    "objective": "binary:logistic",
    "eval_metric": "auc",
    "scale_pos_weight": y_train.value_counts()[0] / y_train.value_counts()[1],  # Adjust for class imbalance
    "learning_rate": 0.01,
    "max_depth": 6,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "gamma": 2,
    "lambda": 1,
    "alpha": 0.5,
    "min_child_weight": 10
}

# Convert dataset to XGBoost DMatrix format
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Train model
model = xgb.train(params, dtrain, num_boost_round=5000, 
                  evals=[(dtest, "test")], 
                  early_stopping_rounds=100, 
                  verbose_eval=200)

# Predict probabilities
y_pred_prob = model.predict(dtest)  # Get probability for class 1

# Compute AUC-PR
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
auc_pr = auc(recall, precision)

print(f"AUC-PR: {auc_pr:.4f}")
# Out:
# [0]	test-auc:0.60719
# [106]	test-auc:0.62319
# AUC-PR: 0.1444

# %%
import lightgbm as lgb
from sklearn.metrics import precision_recall_curve, auc

# Define LightGBM parameters
params = {
    "objective": "binary",
    "metric": "auc",
    "boosting_type": "gbdt",
    "is_unbalance": True,  # Alternatively, use scale_pos_weight
    "learning_rate": 0.01,
    "num_leaves": 31,
    "max_depth": -1,
    "min_data_in_leaf": 20,
    "feature_fraction": 0.8,
    "bagging_fraction": 0.8,
    "bagging_freq": 5,
    "lambda_l1": 0.1,
    "lambda_l2": 0.1,
    "verbosity": -1
}

# Create LightGBM dataset
dtrain = lgb.Dataset(X_train, label=y_train)
dtest = lgb.Dataset(X_test, label=y_test, reference=dtrain)

# Train model
model = lgb.train(params, dtrain, num_boost_round=5000, 
                  valid_sets=[dtest])

# Predict probabilities
y_pred_prob = model.predict(X_test)  # Get probability for class 1

# Compute AUC-PR
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
auc_pr = auc(recall, precision)

print(f"AUC-PR: {auc_pr:.4f}")
# Out:
# AUC-PR: 0.2163
